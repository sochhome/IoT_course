# %% [markdown]
# # Basic Tabular Data Viewing with Temperature and Humidity

# %%
# !pip install pandas Pyarrow
# Out:
# Requirement already satisfied: pandas in d:\soch1\projects\iot_course\.venv\lib\site-packages (2.2.0)
# Requirement already satisfied: Pyarrow in d:\soch1\projects\iot_course\.venv\lib\site-packages (15.0.0)
# Requirement already satisfied: pytz>=2020.1 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'D:\soch1\Projects\IoT_course\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
print(1+1)
# Out:
# 2

# %%
import pandas as pd

# Create a DataFrame with ten records
data = {
    'Temperature': [20, 21, 19, 22, 21, 20, 23, 24, 22, 21],
    'Humidity': [30, 32, 31, 33, 32, 31, 34, 35, 33, 32]
}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('data_tst.csv', index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv('data_tst.csv')

# Display the DataFrame
df
# Out:
#    Temperature  Humidity
# 0           20        30
# 1           21        32
# 2           19        31
# 3           22        33
# 4           21        32
# 5           20        31
# 6           23        34
# 7           24        35
# 8           22        33
# 9           21        32

# %% [markdown]
# ### This data represents the indoor air quality at different times, with temperature in °C, humidity in %, CO2 in ppm (parts per million), and TVOC (Total Volatile Organic Compounds) in ppb (parts per billion). All values are within the recommended ranges for good indoor air quality. Please note that the CO2 and TVOC values are hypothetical and may not represent typical indoor levels

# %%
# Load the data
df = pd.read_csv('latest_telemetry.csv')

df
# Out:
#    Last update time          Key  Value
# 0  20/02/2024 10:44          CO2  403.0
# 1  20/02/2024 10:44     Humidity   44.0
# 2  20/02/2024 10:44         TVOC    0.0
# 3  20/02/2024 10:44  Temperature   20.5

# %%
# Pivot the DataFrame
df_pivot = df.pivot(index='Last update time', columns='Key', values='Value')

# Reset the index
df_pivot.reset_index(inplace=True)

# Save the transformed data
df_pivot.head()
# Out:
# Key  Last update time    CO2  Humidity  TVOC  Temperature
# 0    20/02/2024 10:44  403.0      44.0   0.0         20.5

# %%
def transform_data(latest_telemetry_file, data_file):
    # Load the existing data
    df_data = pd.read_csv(data_file)

    # Load the new data
    df_latest = pd.read_csv(latest_telemetry_file)

    # Pivot the new DataFrame
    df_latest_pivot = df_latest.pivot(index='Lastupdatetime', columns='Key', values='Value')

    # Reset the index
    df_latest_pivot.reset_index(inplace=True)

    # Append the new data to the existing data
    df_combined = pd.concat([df_data, df_latest_pivot])

    return df_combined

# %%
def save_data(df, data_file):
    # Save the combined data
    df.to_csv(data_file, index=False)

# %%
#  check if .csv exists before trying to read it. If it doesn’t exist, it will create an empty DataFrame and save it as .csv
import os

def transform_data(latest_telemetry_file, data_file):
    # Check if data_file exists
    if os.path.exists(data_file):
        # Load the existing data
        df_data = pd.read_csv(data_file)
    else:
        # Create an empty DataFrame with the required columns
        df_data = pd.DataFrame(columns=['Lastupdatetime', 'Temperature', 'Humidity', 'CO2', 'TVOC'])

    # Load the new data
    df_latest = pd.read_csv(latest_telemetry_file)

    df_latest = df_latest.rename(columns={'Last update time': 'Lastupdatetime'})

    # Pivot the new DataFrame
    df_latest_pivot = df_latest.pivot(index='Lastupdatetime', columns='Key', values='Value')

    # Reset the index
    df_latest_pivot.reset_index(inplace=True)

    # Append the new data to the existing data
    df_combined = pd.concat([df_data, df_latest_pivot])

    return df_combined

# %% [markdown]
# ## Main Function

# %%
latest_telemetry_file = 'latest_telemetry.csv'
data_file = 'data01.csv'

# %%
# Unccomment when new data are available
# df_combined = transform_data(latest_telemetry_file, data_file)
# save_data(df_combined, data_file)

# %%
aq = pd.read_csv('data01.csv')
aq.tail()
# Out:
#         Lastupdatetime  Temperature  Humidity    CO2  TVOC
# 1553  03/03/2024 05:14         20.5      58.6  409.5   0.0
# 1554  03/03/2024 05:24         20.5      44.0  403.0   0.0
# 1555  03/03/2024 05:34         20.0      54.0  402.0   0.0
# 1556  03/03/2024 05:44         21.5      44.0  403.0   0.0
# 1557  20/02/2024 10:44         20.5      44.0  403.0   0.0

# %%
aq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1558 entries, 0 to 1557
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Lastupdatetime  1558 non-null   object
#  1   Temperature     1558 non-null   float64
#  2   Humidity        1558 non-null   float64
#  3   CO2             1558 non-null   float64
#  4   TVOC            1558 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 61.0+ KB

# %% [markdown]
# ## Plot Simple Graphs

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))

# %%
# Temperature graph
plt.subplot(2, 1, 1)  # 2 rows, 1 column, 1st subplot
plt.plot(aq['Lastupdatetime'], aq['Temperature'], color='red')
plt.title('Temperature across the day')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
# Out:
# Text(0, 0.5, 'Temperature (°C)')

# %%
plt.show()

# %%
from datetime import datetime, timedelta

# Get the current time
now = datetime.now()

# Calculate the time 24 hours ago
one_day_ago = now - timedelta(days=1)

# Convert 'Lastupdatetime' to datetime format
#aq['Lastupdatetime'] = pd.to_datetime(aq['Lastupdatetime'])
aq['Lastupdatetime'] = pd.to_datetime(aq['Lastupdatetime'], format='%d-%m-%Y %H:%M:%S')

# Filter the DataFrame to only include data from the last 24 hours
aq_last_24_hours = aq[aq['Lastupdatetime'] >= one_day_ago]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 11
#       7 one_day_ago = now - timedelta(days=1)
#       9 # Convert 'Lastupdatetime' to datetime format
#      10 #aq['Lastupdatetime'] = pd.to_datetime(aq['Lastupdatetime'])
# ---> 11 aq['Lastupdatetime'] = pd.to_datetime(aq['Lastupdatetime'], format='%d-%m-%Y %H:%M:%S')
#      13 # Filter the DataFrame to only include data from the last 24 hours
#      14 aq_last_24_hours = aq[aq['Lastupdatetime'] >= one_day_ago]
#
# File D:\soch1\Projects\IoT_course\.venv\lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File D:\soch1\Projects\IoT_course\.venv\lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File D:\soch1\Projects\IoT_course\.venv\lib\site-packages\pandas\core\tools\datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "20/02/2024 10:34" doesn't match format "%d-%m-%Y %H:%M:%S", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
# Plot the temperature data
plt.figure(figsize=(10, 6))
plt.plot(aq_last_24_hours['Lastupdatetime'], aq_last_24_hours['Temperature'], marker='o')
plt.title('Temperature in the Last 24 Hours')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.grid(True)
plt.show()

# %%
# Plot the humidity data
plt.figure(figsize=(10, 6))
plt.plot(aq_last_24_hours['Lastupdatetime'], aq_last_24_hours['Humidity'], marker='o')
plt.title('Humidity in the Last 24 Hours')
plt.xlabel('Time')
plt.ylabel('Humidity')
plt.grid(True)
plt.show()
