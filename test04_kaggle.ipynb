# %% [markdown]
# ## Reading dataset retrieved form kaggle

# %% [markdown]
# ### https://www.kaggle.com/datasets/fedesoriano/air-quality-data-set?resource=download

# %%
import pandas as pd

# %% [markdown]
# ### Parsing data samples

# %%
from io import StringIO

data = """
Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
10/03/2004;18.00.00;2,6;1360;150;11,9;1046;166;1056;113;1692;1268;13,6;48,9;0,7578;;
10/03/2004;19.00.00;2;1292;112;9,4;955;103;1174;92;1559;972;13,3;47,7;0,7255;;
10/03/2004;20.00.00;2,2;1402;88;9,0;939;131;1140;114;1555;1074;11,9;54,0;0,7502;;
"""

# Convert the string to a file-like object
data = StringIO(data)

# Read the data
df = pd.read_csv(data, sep=";", decimal = ",")

# Print the DataFrame
print(df)
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6         1360       150      11.9
# 1  10/03/2004  19.00.00     2.0         1292       112       9.4
# 2  10/03/2004  20.00.00     2.2         1402        88       9.0
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# 1  13.3  47.7  0.7255          NaN          NaN
# 2  11.9  54.0  0.7502          NaN          NaN

# %% [markdown]
# ### Parsing data from CSV

# %%
aq = pd.read_csv("AirQuality.csv", sep = ";", decimal = ",")        
aq.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# 1  13.3  47.7  0.7255          NaN          NaN
# 2  11.9  54.0  0.7502          NaN          NaN
# 3  11.0  60.0  0.7867          NaN          NaN
# 4  11.2  59.6  0.7888          NaN          NaN

# %% [markdown]
# ## Time Series
# Let's visualize the CO / temperature in hourly basis.

# %%
#For dealing with time string types
import datetime

# %%
aq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
#  17  DateTime       9357 non-null   object
# dtypes: float64(15), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# To remove the rows with NaN values instead, you can use the dropna function

# %%
aq = aq.dropna(subset=['DateTime'])

# %% [markdown]
# Convert the ‘DateTime’ column to datetime format.

# %%
aq['DateTime'] =  (aq.Date) + ' ' + (aq.Time)
aq.DateTime = aq.DateTime.apply(lambda x: datetime.datetime.strptime(x, '%d/%m/%Y %H.%M.%S'))
aq
# Out:
# C:\Users\Joseph\AppData\Local\Temp\ipykernel_6220\2034369123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aq['DateTime'] =  (aq.Date) + ' ' + (aq.Time)
# C:\Users\Joseph\AppData\Local\Temp\ipykernel_6220\2034369123.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aq.DateTime = aq.DateTime.apply(lambda x: datetime.datetime.strptime(x, '%d/%m/%Y %H.%M.%S'))
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16  \
# 0          1268.0  13.6  48.9  0.7578          NaN          NaN
# 1           972.0  13.3  47.7  0.7255          NaN          NaN
# 2          1074.0  11.9  54.0  0.7502          NaN          NaN
# 3          1203.0  11.0  60.0  0.7867          NaN          NaN
# 4          1110.0  11.2  59.6  0.7888          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9352       1729.0  21.9  29.3  0.7568          NaN          NaN
# 9353       1269.0  24.3  23.7  0.7119          NaN          NaN
# 9354       1092.0  26.9  18.3  0.6406          NaN          NaN
# 9355        770.0  28.3  13.5  0.5139          NaN          NaN
# 9356        816.0  28.5  13.1  0.5028          NaN          NaN
#
#                 DateTime
# 0    2004-03-10 18:00:00
# 1    2004-03-10 19:00:00
# 2    2004-03-10 20:00:00
# 3    2004-03-10 21:00:00
# 4    2004-03-10 22:00:00
# ...                  ...
# 9352 2005-04-04 10:00:00
# 9353 2005-04-04 11:00:00
# 9354 2005-04-04 12:00:00
# 9355 2005-04-04 13:00:00
# 9356 2005-04-04 14:00:00
#
# [9357 rows x 18 columns]

# %%
aq['Weekday'] = aq['DateTime'].dt.day_name()
aq['Month']   = aq['DateTime'].dt.month_name()
aq['Hour']    = aq['DateTime'].dt.hour
aq['Date']    = pd.to_datetime(aq['Date'], format='%d/%m/%Y')
aq.drop('Time', axis=1, inplace=True, errors = 'ignore') 
aq.head()
# Out:
# C:\Users\Joseph\AppData\Local\Temp\ipykernel_6220\411182946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aq['Weekday'] = aq['DateTime'].dt.day_name()
# C:\Users\Joseph\AppData\Local\Temp\ipykernel_6220\411182946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aq['Month']   = aq['DateTime'].dt.month_name()
# C:\Users\Joseph\AppData\Local\Temp\ipykernel_6220\411182946.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aq['Hour']    = aq['DateTime'].dt.hour
# C:\Users\Joseph\AppData\Local\Temp\ipykernel_6220\411182946.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aq['Date']    = pd.to_datetime(aq['Date'], format='%d/%m/%Y')
# C:\Users\Joseph\AppData\Local\Temp\ipykernel_6220\411182946.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aq.drop('Time', axis=1, inplace=True, errors = 'ignore')
#         Date  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0 2004-03-10     2.6       1360.0     150.0      11.9         1046.0    166.0
# 1 2004-03-10     2.0       1292.0     112.0       9.4          955.0    103.0
# 2 2004-03-10     2.2       1402.0      88.0       9.0          939.0    131.0
# 3 2004-03-10     2.2       1376.0      80.0       9.2          948.0    172.0
# 4 2004-03-10     1.6       1272.0      51.0       6.5          836.0    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  \
# 0        1056.0    113.0        1692.0       1268.0  13.6  48.9  0.7578
# 1        1174.0     92.0        1559.0        972.0  13.3  47.7  0.7255
# 2        1140.0    114.0        1555.0       1074.0  11.9  54.0  0.7502
# 3        1092.0    122.0        1584.0       1203.0  11.0  60.0  0.7867
# 4        1205.0    116.0        1490.0       1110.0  11.2  59.6  0.7888
#
#    Unnamed: 15  Unnamed: 16            DateTime    Weekday  Month  Hour
# 0          NaN          NaN 2004-03-10 18:00:00  Wednesday  March    18
# 1          NaN          NaN 2004-03-10 19:00:00  Wednesday  March    19
# 2          NaN          NaN 2004-03-10 20:00:00  Wednesday  March    20
# 3          NaN          NaN 2004-03-10 21:00:00  Wednesday  March    21
# 4          NaN          NaN 2004-03-10 22:00:00  Wednesday  March    22

# %%
aq = aq[['Date','Month', 'Weekday','DateTime', 'Hour', 'CO(GT)','PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)', 
         'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']]
aq.head()
# Out:
#         Date  Month    Weekday            DateTime  Hour  CO(GT)  PT08.S1(CO)  \
# 0 2004-03-10  March  Wednesday 2004-03-10 18:00:00    18     2.6       1360.0
# 1 2004-03-10  March  Wednesday 2004-03-10 19:00:00    19     2.0       1292.0
# 2 2004-03-10  March  Wednesday 2004-03-10 20:00:00    20     2.2       1402.0
# 3 2004-03-10  March  Wednesday 2004-03-10 21:00:00    21     2.2       1376.0
# 4 2004-03-10  March  Wednesday 2004-03-10 22:00:00    22     1.6       1272.0
#
#    C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0      11.9         1046.0    166.0        1056.0    113.0        1692.0
# 1       9.4          955.0    103.0        1174.0     92.0        1559.0
# 2       9.0          939.0    131.0        1140.0    114.0        1555.0
# 3       9.2          948.0    172.0        1092.0    122.0        1584.0
# 4       6.5          836.0    131.0        1205.0    116.0        1490.0
#
#    PT08.S5(O3)     T    RH      AH
# 0       1268.0  13.6  48.9  0.7578
# 1        972.0  13.3  47.7  0.7255
# 2       1074.0  11.9  54.0  0.7502
# 3       1203.0  11.0  60.0  0.7867
# 4       1110.0  11.2  59.6  0.7888

# %%
month_df_list = []
day_df_list   = []
hour_df_list  = []

months = ['January','February','March', 'April', 'May','June', 
          'July', 'August', 'September', 'October', 'November', 'December']

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

for month in months:
    temp_df = aq.loc[(aq['Month'] == month)]
    month_df_list.append(temp_df)

for day in days:
    temp_df = aq.loc[(aq['Weekday'] == day)]
    day_df_list.append(temp_df)

for hour in range(24):
    temp_df = aq.loc[(aq['Hour'] == hour)]
    hour_df_list.append(temp_df)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.3-cp39-cp39-win_amd64.whl (7.6 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Collecting pillow>=8
#   Using cached pillow-10.2.0-cp39-cp39-win_amd64.whl (2.6 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
# Requirement already satisfied: numpy<2,>=1.21 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.2.0-cp39-cp39-win_amd64.whl (181 kB)
# Requirement already satisfied: packaging>=20.0 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.49.0-cp39-cp39-win_amd64.whl (2.2 MB)
# Requirement already satisfied: zipp>=3.1.0 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in d:\soch1\projects\iot_course\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 importlib-resources-6.1.1 kiwisolver-1.4.5 matplotlib-3.8.3 pillow-10.2.0 pyparsing-3.1.1
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'D:\soch1\Projects\IoT_course\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
#For plotting
import matplotlib.pyplot as plt

# %%
def df_time_plotter(df_list, time_unit, y_col):
    
    months = ['January','February','March', 'April', 'May','June', 
              'July', 'August', 'September', 'October', 'November', 'December']
    
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    
    if time_unit == 'M':
        nRows = 3
        nCols = 4
        n_iter = len(months)
    elif time_unit == 'D':
        nRows = 2
        nCols = 4
        n_iter = len(days)
    elif time_unit == 'H':
        nRows = 4
        nCols = 6
        n_iter = 24
    else:
        print('time_unit must be a string equal to M,D, or H')
        return 0
        
    fig, axs = plt.subplots(nrows=nRows, ncols=nCols, figsize = (40,30))
    axs = axs.ravel()
    for i in range(n_iter):
        data = df_list[i]
        ax = axs[i]
        data.plot(kind ='scatter', x = 'DateTime', y= y_col , ax = ax, fontsize = 24)
        ax.set_ylabel('Pollutant Concentration',fontsize=30)
        ax.set_xlabel('')
        if time_unit == 'M':
            ax.set_title(y_col + ' ' + months[i],  size=40) # Title
        elif time_unit == 'D':
            ax.set_title(y_col + ' ' + days[i],  size=40) # Title
        else:
             ax.set_title(y_col + ' ' + str(i),  size=40) # Title
        ax.tick_params(labelrotation=60)

        #plt.xlim([datetime.date(2004, 3, 10), datetime.date(2004, 3, 30)])
    # set the spacing between subplots
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.5)
    plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %%
df_time_plotter(month_df_list,'M','PT08.S1(CO)')
